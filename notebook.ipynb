# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 34.0 MB/s eta 0:00:00
# ...

# %%
# !python3 train.py
# Out:
# Using device: cuda
# Loading annotated dataset...
# Loaded 1 images with annotations
# Dataset size: 1 images
# Creating model...
# Model parameters: 238647936
# Loading YOLO model...
# Starting training...
# Epoch 1:   0% 0/1 [00:00<?, ?it/s]/content/train.py:290: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   detection_loss = torch.tensor(detection_loss, device=device, requires_grad=True)
# Epoch 1: 100% 1/1 [00:00<00:00,  1.32it/s, loss=0.7608, det=0.5996, color=0.0322]
#
# Epoch 1/250:
#   Avg Loss: 0.7608
#   Detection Loss: 0.5996
#   Color Loss: 0.0322
#   LR: 0.000300
#   Saved best model!
# Epoch 2: 100% 1/1 [00:00<00:00,  7.56it/s, loss=0.7475, det=0.6606, color=0.0174]
#
# Epoch 2/250:
#   Avg Loss: 0.7475
#   Detection Loss: 0.6606
#   Color Loss: 0.0174
#   LR: 0.000300
#   Saved best model!
# ...
